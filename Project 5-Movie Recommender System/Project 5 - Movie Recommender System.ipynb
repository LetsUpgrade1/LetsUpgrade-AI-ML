# %% [markdown]
# # Importing libraries and the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')
df = pd.read_csv('movies_metadata.csv', low_memory=False)
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %% [markdown]
# # Understanding Data by EDA

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df.tail()
# Out:
#        adult belongs_to_collection budget  \
# 45461  False                   NaN      0
# 45462  False                   NaN      0
# 45463  False                   NaN      0
# 45464  False                   NaN      0
# 45465  False                   NaN      0
#
#                                                   genres  \
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
df.shape
# Out:
# (45466, 24)

# %%
df.describe()
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %% [markdown]
# # Univariate Analysis

# %%
df["vote_average"].hist(bins=20)

# %%
df["vote_count"].hist(bins=20)

# %%
sns.boxplot(df['vote_average'])

# %%
sns.boxplot(df['vote_count'])

# %% [markdown]
# # Building Recommender System with NaN values

# %%
c=df['vote_average'].mean()
c
# Out:
# 5.618207215133889

# %%
m=df['vote_count'].quantile(0.9)
m
# Out:
# 160.0

# %%
qm=df[(df['runtime']>150)&(df['revenue']>300000000)&(df['homepage'].notna())]

# %%
qm=qm[qm['vote_count']>=m]

# %%
qm.head()
# Out:
#       adult                              belongs_to_collection     budget  \
# 522   False                                                NaN   22000000
# 1639  False                                                NaN  200000000
# 4766  False  {'id': 1241, 'name': 'Harry Potter Collection'...  125000000
# 4863  False  {'id': 119, 'name': 'The Lord of the Rings Col...   93000000
# 5814  False  {'id': 119, 'name': 'The Lord of the Rings Col...   79000000
#
#                                                  genres  \
# 522   [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 1639  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4766  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 4863  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 5814  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                                homepage   id    imdb_id  \
# 522                      http://www.schindlerslist.com/  424  tt0108052
# ...

# %%
qm.shape
# Out:
# (27, 24)

# %%
def wr(x,m=m,c=c):
    v=x['vote_count']
    r=x['vote_average']
    return (v/(v+m)*r)+(m/(m+v)*c)

# %%
qm['score']=qm.apply(wr,axis=1)

# %%
qm.head()
# Out:
#       adult                              belongs_to_collection     budget  \
# 522   False                                                NaN   22000000
# 1639  False                                                NaN  200000000
# 4766  False  {'id': 1241, 'name': 'Harry Potter Collection'...  125000000
# 4863  False  {'id': 119, 'name': 'The Lord of the Rings Col...   93000000
# 5814  False  {'id': 119, 'name': 'The Lord of the Rings Col...   79000000
#
#                                                  genres  \
# 522   [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 1639  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4766  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 4863  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 5814  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                                homepage   id    imdb_id  \
# 522                      http://www.schindlerslist.com/  424  tt0108052
# ...

# %%
qm=qm.sort_values('score',ascending=False)

# %%
qm[['title','vote_count','vote_average','score']].head(10)
# Out:
#                                                    title  vote_count  \
# 12481                                    The Dark Knight     12269.0
# 522                                     Schindler's List      4436.0
# 22879                                       Interstellar     11187.0
# 7000       The Lord of the Rings: The Return of the King      8226.0
# 4863   The Lord of the Rings: The Fellowship of the Ring      8892.0
# 5814               The Lord of the Rings: The Two Towers      7641.0
# 22131                            The Wolf of Wall Street      6768.0
# 13605                               Inglourious Basterds      6598.0
# 20051                                   Django Unchained     10297.0
# 18252                              The Dark Knight Rises      9263.0
#
#        vote_average     score
# 12481           8.3  8.265477
# 522             8.3  8.206639
# 22879           8.1  8.065005
# 7000            8.1  8.052649
# 4863            8.0  7.957900
# ...

# %%
d=df.sort_values('vote_count',ascending=False)
plt.figure(figsize=(18,6))

plt.barh(d['title'].head(15),d['vote_count'].head(15),align='center',color='cornflowerblue')
plt.gca().invert_yaxis()
plt.xlabel("Votes")
plt.title("MOst voted Movies")
# Out:
# Text(0.5, 1.0, 'MOst voted Movies')

# %% [markdown]
# # Building Recommender System by dropping the NaN values

# %%
df.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
df1 = df.dropna()
df1.isna().sum()
# Out:
# adult                    0
# belongs_to_collection    0
# budget                   0
# genres                   0
# homepage                 0
# id                       0
# imdb_id                  0
# original_language        0
# original_title           0
# overview                 0
# popularity               0
# poster_path              0
# production_companies     0
# production_countries     0
# release_date             0
# revenue                  0
# runtime                  0
# spoken_languages         0
# status                   0
# tagline                  0
# title                    0
# video                    0
# vote_average             0
# vote_count               0
# dtype: int64

# %%
c1=df1['vote_average'].mean()
c1
# Out:
# 6.270995670995678

# %%
m1=df1['vote_count'].quantile(0.9)
m1
# Out:
# 4881.800000000001

# %%
qm1=df1[(df1['runtime']>150)&(df1['revenue']>300000000)]

# %%
qm1=qm1[qm1['vote_count']>=m1]

# %%
qm1.head()
# Out:
#        adult                              belongs_to_collection     budget  \
# 4766   False  {'id': 1241, 'name': 'Harry Potter Collection'...  125000000
# 4863   False  {'id': 119, 'name': 'The Lord of the Rings Col...   93000000
# 5814   False  {'id': 119, 'name': 'The Lord of the Rings Col...   79000000
# 7000   False  {'id': 119, 'name': 'The Lord of the Rings Col...   94000000
# 10554  False  {'id': 1241, 'name': 'Harry Potter Collection'...  150000000
#
#                                                   genres  \
# 4766   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 4863   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 5814   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 7000   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 10554  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                                 homepage   id    imdb_id  \
# 4766   http://harrypotter.warnerbros.com/harrypottera...  671  tt0241527
# ...

# %%
qm1.shape
# Out:
# (12, 24)

# %%
qm1['score']=qm1.apply(wr,axis=1)

# %%
qm1.head()
# Out:
#        adult                              belongs_to_collection     budget  \
# 4766   False  {'id': 1241, 'name': 'Harry Potter Collection'...  125000000
# 4863   False  {'id': 119, 'name': 'The Lord of the Rings Col...   93000000
# 5814   False  {'id': 119, 'name': 'The Lord of the Rings Col...   79000000
# 7000   False  {'id': 119, 'name': 'The Lord of the Rings Col...   94000000
# 10554  False  {'id': 1241, 'name': 'Harry Potter Collection'...  150000000
#
#                                                   genres  \
# 4766   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 4863   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 5814   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 7000   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 10554  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                                 homepage   id    imdb_id  \
# 4766   http://harrypotter.warnerbros.com/harrypottera...  671  tt0241527
# ...

# %%
qm1=qm1.sort_values('score',ascending=False)

# %%
qm1[['title','vote_count','vote_average','score']].head(10)
# Out:
#                                                    title  vote_count  \
# 12481                                    The Dark Knight     12269.0
# 7000       The Lord of the Rings: The Return of the King      8226.0
# 4863   The Lord of the Rings: The Fellowship of the Ring      8892.0
# 5814               The Lord of the Rings: The Two Towers      7641.0
# 18252                              The Dark Knight Rises      9263.0
# 4766            Harry Potter and the Philosopher's Stone      7188.0
# 10554                Harry Potter and the Goblet of Fire      5758.0
# 13893             Harry Potter and the Half-Blood Prince      5435.0
# 14551                                             Avatar     12114.0
# 19971                  The Hobbit: An Unexpected Journey      8427.0
#
#        vote_average     score
# 12481           8.3  8.265477
# 7000            8.1  8.052649
# 4863            8.0  7.957900
# 5814            8.0  7.951149
# 18252           7.6  7.566350
# ...

# %%
d1=df1.sort_values('vote_count',ascending=False)
plt.figure(figsize=(18,6))

plt.barh(d1['title'].head(15),d1['vote_count'].head(15),align='center',color='cornflowerblue')
plt.gca().invert_yaxis()
plt.xlabel("Votes")
plt.title("MOst voted Movies")
# Out:
# Text(0.5, 1.0, 'MOst voted Movies')

# %% [markdown]
# # Building Recommender System by filling the NaN values

# %%
df2 = df.fillna(method='bfill')
df2.isna().sum()
# Out:
# adult                     0
# belongs_to_collection    83
# budget                    0
# genres                    0
# homepage                  4
# id                        0
# imdb_id                   0
# original_language         0
# original_title            0
# overview                  0
# popularity                0
# poster_path               0
# production_companies      0
# production_countries      0
# release_date              0
# revenue                   0
# runtime                   0
# spoken_languages          0
# status                    0
# tagline                   2
# title                     0
# video                     0
# vote_average              0
# vote_count                0
# dtype: int64

# %%
# Still we have some null values but the count is less so we can drop them
df2.dropna(inplace=True)
df2.isna().sum()
# Out:
# adult                    0
# belongs_to_collection    0
# budget                   0
# genres                   0
# homepage                 0
# id                       0
# imdb_id                  0
# original_language        0
# original_title           0
# overview                 0
# popularity               0
# poster_path              0
# production_companies     0
# production_countries     0
# release_date             0
# revenue                  0
# runtime                  0
# spoken_languages         0
# status                   0
# tagline                  0
# title                    0
# video                    0
# vote_average             0
# vote_count               0
# dtype: int64

# %%
c2=df2['vote_average'].mean()
c2
# Out:
# 5.619079831654733

# %%
m2=df2['vote_count'].quantile(0.9)
m2
# Out:
# 161.0

# %%
qm2=df2[(df2['runtime']>150)&(df2['revenue']>300000000)]

# %%
m2=qm2[qm2['vote_count']>=m2]

# %%
qm2.head()
# Out:
#       adult                              belongs_to_collection     budget  \
# 522   False  {'id': 462565, 'name': 'The Secret Garden Coll...   22000000
# 583   False  {'id': 120794, 'name': 'Batman Collection', 'p...   22000000
# 893   False  {'id': 4438, 'name': 'The Space Odyssey Series...    4000000
# 1639  False  {'id': 645, 'name': 'James Bond Collection', '...  200000000
# 1808  False  {'id': 945, 'name': 'Lethal Weapon Collection'...  140000000
#
#                                                  genres  \
# 522   [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 583   [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 893   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 1639  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 1808  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                                homepage   id    imdb_id  \
# 522                      http://www.schindlerslist.com/  424  tt0108052
# ...

# %%
qm2.shape
# Out:
# (38, 24)

# %%
qm2['score']=qm2.apply(wr,axis=1)

# %%
qm2.head()
# Out:
#       adult                              belongs_to_collection     budget  \
# 522   False  {'id': 462565, 'name': 'The Secret Garden Coll...   22000000
# 583   False  {'id': 120794, 'name': 'Batman Collection', 'p...   22000000
# 893   False  {'id': 4438, 'name': 'The Space Odyssey Series...    4000000
# 1639  False  {'id': 645, 'name': 'James Bond Collection', '...  200000000
# 1808  False  {'id': 945, 'name': 'Lethal Weapon Collection'...  140000000
#
#                                                  genres  \
# 522   [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 583   [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 893   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 1639  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 1808  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                                homepage   id    imdb_id  \
# 522                      http://www.schindlerslist.com/  424  tt0108052
# ...

# %%
qm2=qm2.sort_values('score',ascending=False)

# %%
qm2[['title','vote_count','vote_average','score']].head(10)
# Out:
#                                                    title  vote_count  \
# 12481                                    The Dark Knight     12269.0
# 522                                     Schindler's List      4436.0
# 22879                                       Interstellar     11187.0
# 7000       The Lord of the Rings: The Return of the King      8226.0
# 4863   The Lord of the Rings: The Fellowship of the Ring      8892.0
# 5814               The Lord of the Rings: The Two Towers      7641.0
# 22131                            The Wolf of Wall Street      6768.0
# 13605                               Inglourious Basterds      6598.0
# 3456                                           Gladiator      5566.0
# 1919                                 Saving Private Ryan      5148.0
#
#        vote_average     score
# 12481           8.3  8.265477
# 522             8.3  8.206639
# 22879           8.1  8.065005
# 7000            8.1  8.052649
# 4863            8.0  7.957900
# ...

# %%
d2=df2.sort_values('vote_count',ascending=False)
plt.figure(figsize=(18,6))

plt.barh(d2['title'].head(15),d2['vote_count'].head(15),align='center',color='cornflowerblue')
plt.gca().invert_yaxis()
plt.xlabel("Votes")
plt.title("MOst voted Movies")
# Out:
# Text(0.5, 1.0, 'MOst voted Movies')

# %% [raw]
# Here, we observe by dropping the NaN values some of the movies like (Inception, Fight Club, etc) are not getting recommended.
# If we consider the NaN values or if we fill them we get almost the same recommendations.
# So, it is better to fill the NaN values or to use the NaN values instead of dropping them.
